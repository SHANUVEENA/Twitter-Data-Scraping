# %% [markdown]
# <a href="https://colab.research.google.com/github/SHANUVEENA/Twitter-Data-Scraping/blob/main/Twitter_Data_Scrping_using_Snscrape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install snscrape # Installing Snsrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: snscrape in /usr/local/lib/python3.8/dist-packages (0.5.0.20230113)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from snscrape) (2022.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from snscrape) (3.9.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from snscrape) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2022.12.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.7.1)

# %%
#Importing Library and Pacakges
import snscrape.modules.twitter as sntwitter 
import pandas as pd

# %%
username = input('Enter the Username: ') #Username of the Twitter
number = int(1000) #Maximum no of Tweets Required

tweet_data = [] #Created list to Append Tweets Data

# Using TwitterSearchScraper to scrape data 
for i,tweets in enumerate(sntwitter.TwitterSearchScraper('{}'.format(username)).get_items()):
  if i>number:
    break
#Appending the Tweets data to Created list
  tweet_data.append([tweets.date, tweets.id, tweets.url, tweets.content, tweets.user.username, tweets.replyCount, tweets.retweetCount, tweets.lang, tweets.source, tweets.likeCount,   ])

# Creating a dataframe from the tweets list
df = pd.DataFrame(tweet_data, columns=['Date', 'ID', 'Url', 'Tweet_Content', 'Username',  'Reply_Count', 'Retweet_Count', 'Language', 'Source', 'Like_Count'])
# Out:
# Enter the Username: elonmusk
# <ipython-input-15-4de9e078c0bc>:11: FutureWarning: content is deprecated, use rawContent instead
#   tweet_data.append([tweets.date, tweets.id, tweets.url, tweets.content, tweets.user.username, tweets.replyCount, tweets.retweetCount, tweets.lang, tweets.source, tweets.likeCount,   ])
#                           Date                   ID  \
# 0    2023-01-26 04:18:22+00:00  1618463330791985153
# 1    2023-01-26 04:18:22+00:00  1618463330771013633
# 2    2023-01-26 04:18:21+00:00  1618463328631951360
# 3    2023-01-26 04:18:21+00:00  1618463325385551874
# 4    2023-01-26 04:18:20+00:00  1618463325112930306
# ...                        ...                  ...
# 996  2023-01-26 04:12:03+00:00  1618461743470239744
# 997  2023-01-26 04:12:03+00:00  1618461743025655809
# 998  2023-01-26 04:12:03+00:00  1618461742719279104
# 999  2023-01-26 04:12:03+00:00  1618461742669103104
# 1000 2023-01-26 04:12:02+00:00  1618461736398639105
#
#                                                     Url  \
# 0     https://twitter.com/938433911/status/161846333...
# 1     https://twitter.com/Teslaconomics/status/16184...
# 2     https://twitter.com/blabbymouthjay/status/1618...
# 3     https://twitter.com/freak4him4ever/status/1618...
# 4     https://twitter.com/BenjimanHughey/status/1618...
# ...                                                 ...
# 996   https://twitter.com/AllieCat8844/status/161846...
# 997   https://twitter.com/FUTURENEWS2020/status/1618...
# 998   https://twitter.com/Ukbucketlist22/status/1618...
# 999   https://twitter.com/DeesK39042/status/16184617...
# 1000  https://twitter.com/GoldenMile11/status/161846...
#
#                                           Tweet_Content        Username  \
# 0                   @lucky_dogecoin @elonmusk 用来做推特内容激励       938433911
# 1     Average selling price decreasing, while operat...   Teslaconomics
# 2     @jonastyle_ \n\nSomeone said \n“Hey mfr , you ...  blabbymouthjay
# 3     @MattH_4America @Hotel2a @elonmusk No one mess...  freak4him4ever
# 4     @DrAnitaBEtin @elonmusk Pretty sure there are ...  BenjimanHughey
# ...                                                 ...             ...
# 996   @DrAnitaBEtin @elonmusk Where is the responsib...    AllieCat8844
# 997   @JamesOKeefeIII @Project_Veritas @elonmusk htt...  FUTURENEWS2020
# 998   @MarioFratto @elonmusk Creepy Joe sounds good ...  Ukbucketlist22
# 999   Thank You @elonmusk for helping expose the tru...      DeesK39042
# 1000  @TonyadeVitti @kerrikgray @dvorahfr @SweetSire...    GoldenMile11
#
#       Reply_Count  Retweet_Count Language  \
# 0               0              0       zh
# 1               0              0       en
# 2               0              0       en
# 3               0              0       en
# 4               0              0       en
# ...           ...            ...      ...
# 996             0              0       en
# 997             0              0      qme
# 998             0              0       en
# 999             0              0       en
# 1000            0              0      und
#
#                                                  Source  Like_Count
# 0     <a href="http://twitter.com/download/android" ...           0
# 1     <a href="http://twitter.com/download/iphone" r...           0
# 2     <a href="http://twitter.com/download/iphone" r...           0
# 3     <a href="http://twitter.com/download/android" ...           0
# 4     <a href="http://twitter.com/download/iphone" r...           0
# ...                                                 ...         ...
# 996   <a href="https://mobile.twitter.com" rel="nofo...           0
# 997   <a href="http://twitter.com/download/iphone" r...           0
# 998   <a href="http://twitter.com/download/android" ...           0
# 999   <a href="http://twitter.com/download/iphone" r...           0
# 1000  <a href="http://twitter.com/download/android" ...           1
#
# [1001 rows x 10 columns]
